# %% [markdown]
# # Лабораторная работа №8

# %% [markdown]
# ## Баканов Сергей ИБМ3-65Б

# %%
import streamlit

# %%
# !streamlit run app.py

# %% [markdown]
# ### Меню

# %% [markdown]
# ![](menu.jpg)

# %% [markdown]
# Видно первые 5 объектов датасета. Можно изменять размер тестовой выбоки от 0,1 до 0,5.

# %% [markdown]
# ### Возможность выбрать целевой признак (только числовое значение).

# %% [markdown]
# ![](prediction.jpg)

# %% [markdown]
# ### Возможность выбрать модель обучения.

# %% [markdown]
# ![](models.jpg)

# %% [markdown]
# После обучения выводятся основные метрики и график сравнения фактических данных от прогноза.

# %% [markdown]
# ![](result.jpg)
